# %% [markdown]
# **Question 1- Delivery time**

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
data=pd.read_csv("/content/delivery_time.csv")

# %%
data.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
data.tail()
# Out:
#     Delivery Time  Sorting Time
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %% [markdown]
# **EDA**

# %%
data.shape
# Out:
# (21, 2)

# %%
data.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
data.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
data.dropna().value_counts()
# Out:
# Delivery Time  Sorting Time
# 8.00           2               1
# 17.90          10              1
# 24.00          9               1
# 21.50          5               1
# 21.00          10              1
# 19.83          8               1
# 19.75          6               1
# 19.00          7               1
# 18.75          9               1
# 18.11          7               1
# 17.83          7               1
# 9.50           3               1
# 16.68          7               1
# 15.35          6               1
# 14.88          4               1
# 13.75          6               1
# 13.50          4               1
# 12.03          3               1
# 11.50          3               1
# 10.75          4               1
# 29.00          10              1
# Name: count, dtype: int64

# %% [markdown]
# **Visualization**

# %%
#Scatter Plot
x = data['Sorting Time']
y = data['Delivery Time']

# %%
b, m = np.polyfit(x, y, 1)
plt.scatter(x, y)
plt.plot(x, y, '.')
plt.plot(x, b + m * x, '-')
plt.title('Scatter plot delivery_time')
plt.xlabel('Sorting Time')
plt.ylabel('delivery_time')
plt.show()

# %%
plt.boxplot(data['Delivery Time']) #checking for outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79a8b09555a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79a8b09561d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79a8b09552d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x79a8b0956680>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79a8b09566e0>],
#  'means': []}

# %%
plt.boxplot(data['Sorting Time']) #checking for outliers
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x79a8b06c3ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x79a8b06f0040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x79a8b06c3820>],
#  'medians': [<matplotlib.lines.Line2D at 0x79a8b06f0580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x79a8b06f0820>],
#  'means': []}

# %%
sns.distplot(data['Delivery Time'])
# Out:
# <ipython-input-70-fd8df65c5d1c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Delivery Time'])
# <Axes: xlabel='Delivery Time', ylabel='Density'>

# %%
sns.distplot(data['Sorting Time'])
# Out:
# <ipython-input-71-971e7a7bfcf0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Sorting Time'])
# <Axes: xlabel='Sorting Time', ylabel='Density'>

# %%
data.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %% [markdown]
# **Model** **Building**

# %%
data=data.rename({'Delivery Time':'delivery_time','Sorting Time':'sorting_time'},axis=1)
data
# Out:
#     delivery_time  sorting_time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
model=smf.ols('delivery_time~sorting_time', data=data).fit()

# %%
model.params
# Out:
# Intercept       6.582734
# sorting_time    1.649020
# dtype: float64

# %%
(model.rsquared, model.rsquared_adj)
# Out:
# (0.6822714748417231, 0.6655489208860244)

# %%
sns.regplot(x='sorting_time', y='delivery_time', data=data, color='purple')
# Out:
# <Axes: xlabel='sorting_time', ylabel='delivery_time'>

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept       3.823349
# sorting_time    6.387447
# dtype: float64
#  Intercept       0.001147
# sorting_time    0.000004
# dtype: float64

# %%
newdata=pd.Series([20,50,4])

# %%
newdata
# Out:
# 0    20
# 1    50
# 2     4
# dtype: int64

# %%
data_pred=pd.DataFrame(newdata,columns=['sorting_time'])
data_pred
# Out:
#    sorting_time
# 0            20
# 1            50
# 2             4

# %%
model.predict(data_pred)
# Out:
# 0    39.563132
# 1    89.033729
# 2    13.178814
# dtype: float64

# %%
x_sqrt = np.sqrt(data['sorting_time'])

# %%
model = sm.OLS(y, x_sqrt).fit()
predications = model.predict(x_sqrt)
model

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          Delivery Time   R-squared (uncentered):                   0.975
# Model:                            OLS   Adj. R-squared (uncentered):              0.973
# Method:                 Least Squares   F-statistic:                              772.0
# Date:                Sat, 17 Aug 2024   Prob (F-statistic):                    1.88e-17
# Time:                        07:53:34   Log-Likelihood:                         -51.284
# No. Observations:                  21   AIC:                                      104.6
# Df Residuals:                      20   BIC:                                      105.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
y_sqrt = np.sqrt(data['delivery_time'])

# %%
model = sm.OLS(y_sqrt, x).fit()
predications = model.predict(x)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          delivery_time   R-squared (uncentered):                   0.930
# Model:                            OLS   Adj. R-squared (uncentered):              0.927
# Method:                 Least Squares   F-statistic:                              266.0
# Date:                Sat, 17 Aug 2024   Prob (F-statistic):                    5.09e-13
# Time:                        07:54:32   Log-Likelihood:                         -31.484
# No. Observations:                  21   AIC:                                      64.97
# Df Residuals:                      20   BIC:                                      66.01
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_sqrt, x_sqrt).fit()
predications = model.predict(x_sqrt)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:          delivery_time   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              1542.
# Date:                Sat, 17 Aug 2024   Prob (F-statistic):                    2.10e-20
# Time:                        07:55:01   Log-Likelihood:                         -13.658
# No. Observations:                  21   AIC:                                      29.32
# Df Residuals:                      20   BIC:                                      30.36
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Question 2- Salary Dataset**

# %%
salary=pd.read_csv("/content/Salary_Data.csv")

# %%
salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# **EDA**

# %%
salary.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
salary.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
salary.shape
# Out:
# (30, 2)

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
salary.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
salary.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
salary.dropna().value_counts()
# Out:
# YearsExperience  Salary
# 1.1              39343.0     1
# 1.3              46205.0     1
# 10.3             122391.0    1
# 9.6              112635.0    1
# 9.5              116969.0    1
# 9.0              105582.0    1
# 8.7              109431.0    1
# 8.2              113812.0    1
# 7.9              101302.0    1
# 7.1              98273.0     1
# 6.8              91738.0     1
# 6.0              93940.0     1
# 5.9              81363.0     1
# 5.3              83088.0     1
# 5.1              66029.0     1
# 4.9              67938.0     1
# 4.5              61111.0     1
# 4.1              57081.0     1
# 4.0              56957.0     1
#                  55794.0     1
# 3.9              63218.0     1
# 3.7              57189.0     1
# 3.2              64445.0     1
#                  54445.0     1
# 3.0              60150.0     1
# 2.9              56642.0     1
# 2.2              39891.0     1
# 2.0              43525.0     1
# 1.5              37731.0     1
# ...

# %%
# salary.corr()

# %% [markdown]
# **Visualizations**

# %%
sns.distplot(data['YearsExperience'])
# Out:
# <ipython-input-32-ab2eeefaaf36>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(salary['YearsExperience'])
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
sns.distplot(salary['Salary'])
# Out:
# <ipython-input-36-36cdd9539e89>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(salary['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %% [markdown]
# **Model Building**

# %%
model = smf.ols("Salary~YearsExperience", data=salary).fit()

# %%
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
(model.rsquared, model.rsquared_adj)
# Out:
# (0.9569566641435086, 0.9554194021486339)

# %%
sns.regplot(x='YearsExperience', y='Salary', data=salary, color='red')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept          11.346940
# YearsExperience    24.950094
# dtype: float64
#  Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %%
newdata=pd.Series([1.2,2.3])

# %%
newdata
# Out:
# 0    1.2
# 1    2.3
# dtype: float64

# %%
data_pred=pd.DataFrame(newdata,columns=['YearsExperience'])

# %%
data_pred
# Out:
#    YearsExperience
# 0              1.2
# 1              2.3

# %%
model.predict(data_pred)
# Out:
# 0    37132.154984
# 1    47527.113538
# dtype: float64

# %%
x_sqrt = np.sqrt(salary['YearsExperience'])

# %%
# !pip install statsmodels
import statsmodels.api as sm

x_sqrt = np.sqrt(salary['YearsExperience'])  # Assuming 'salary' is defined

model = sm.OLS(Y, x_sqrt).fit()  # Now 'sm' is defined
predications = model.predict(x_sqrt)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.989
# Model:                            OLS   Adj. R-squared (uncentered):              0.989
# Method:                 Least Squares   F-statistic:                              2697.
# Date:                Sat, 17 Aug 2024   Prob (F-statistic):                    3.62e-30
# Time:                        07:43:21   Log-Likelihood:                         -313.35
# No. Observations:                  30   AIC:                                      628.7
# Df Residuals:                      29   BIC:                                      630.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
y_sqrt = np.sqrt(salary['Salary'])

# %%
model = sm.OLS(y_sqrt, X).fit()
predications = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.906
# Model:                            OLS   Adj. R-squared (uncentered):              0.902
# Method:                 Least Squares   F-statistic:                              278.1
# Date:                Sat, 17 Aug 2024   Prob (F-statistic):                    2.12e-16
# Time:                        07:44:31   Log-Likelihood:                         -175.75
# No. Observations:                  30   AIC:                                      353.5
# Df Residuals:                      29   BIC:                                      354.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_sqrt, x_sqrt).fit()
predications = model.predict(x_sqrt)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              2338.
# Date:                Sat, 17 Aug 2024   Prob (F-statistic):                    2.81e-29
# Time:                        07:45:26   Log-Likelihood:                         -145.12
# No. Observations:                  30   AIC:                                      292.2
# Df Residuals:                      29   BIC:                                      293.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...
